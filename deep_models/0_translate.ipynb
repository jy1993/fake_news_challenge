# %%
from joblib import Parallel, delayed
from textblob import TextBlob
from textblob.translate import NotTranslated

import os
import pandas as pd

# %%
def translate(comment, language):
    if hasattr(comment, "decode"):
        comment = comment.decode("utf-8")

    text = TextBlob(comment)
    try:
        text = text.translate(to=language)
        text = text.translate(to="en")
    except NotTranslated:
        pass

    return str(text)

# %%
train_data = pd.read_csv('./tmp/train.csv')
comments_list = train_data['articleBody'].tolist()
parallel = Parallel(300, backend="threading", verbose=5)
for language in ["es", "de", "fr"]:
    print('Translate comments using "{0}" language'.format(language))
    translated_data = parallel(delayed(translate)(comment, language) for comment in comments_list)
    train_data["comment_text"] = translated_data

    result_path = os.path.join('./tmp', "train_" + language + ".csv")
    train_data.to_csv(result_path, index=False)
# Out:
# Translate comments using "es" language
# [Parallel(n_jobs=300)]: Using backend ThreadingBackend with 300 concurrent workers.
# [Parallel(n_jobs=300)]: Done  48 tasks      | elapsed:   10.8s
# [Parallel(n_jobs=300)]: Done 282 tasks      | elapsed:   20.3s
# [Parallel(n_jobs=300)]: Done 552 tasks      | elapsed:   31.6s
# [Parallel(n_jobs=300)]: Done 858 tasks      | elapsed:   40.7s
# [Parallel(n_jobs=300)]: Done 1200 tasks      | elapsed:   50.0s
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# C:\Users\yanji\Anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1317                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1318                           encode_chunked=req.has_header('Transfer-encoding'))
#    1319             except OSError as err: # timeout error
#
# ...

# %%
train_data = pd.read_csv('./tmp/train.csv')
a = train_data['Headline'].tolist()[0]

# %%
translate(a, 'es')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-4-d130c498e1c1> in <module>()
# ----> 1 translate(a, 'es')
#
# <ipython-input-2-5e5c8a732198> in translate(comment, language)
#       5     text = TextBlob(comment)
#       6     try:
# ----> 7         text = text.translate(to=language)
#       8         text = text.translate(to="en")
#       9     except NotTranslated:
#
# C:\Users\yanji\Anaconda3\lib\site-packages\textblob\blob.py in translate(self, from_lang, to)
#     539         """
#     540         return self.__class__(self.translator.translate(self.raw,
# --> 541                               from_lang=from_lang, to_lang=to))
#     542
#     543     def detect_language(self):
#
# C:\Users\yanji\Anaconda3\lib\site-packages\textblob\translate.py in translate(self, source, from_lang, to_lang, host, type_)
#      52             tk=_calculate_tk(source),
# ...
